# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import urllib

# %%
options = Options()
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

options.add_experimental_option('detach', True) #브라우저 닫힘방지

# %%
driver = webdriver.Chrome(executable_path='../../../../', options=options)
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="097a7fa638c2b2ff1839f6c95eeeade5")>

# %%
driver = webdriver.Chrome(options=options)
driver.get('https://naver.com')
elem = driver.find_element(By.CLASS_NAME , "search_input")
elem.send_keys("장롱")
elem.send_keys(Keys.RETURN)
time.sleep(0.5)
elem = driver.find_element(By.XPATH,'//*[@id="lnb"]/div[1]/div/div[1]/div/div[1]/div[2]/a')
elem.click()

# %%
#스크롤 끝까지 내리기
PAUSE_TIME = 1
last_hegiht = driver.execute_script("return document.body.scrollHeight")
new_height = 0

while True :
    driver.execute_script("window.scrollBy(0,5000)")
    time.sleep(PAUSE_TIME)
    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height - last_hegiht > 0 :
        last_hegiht = new_height
        continue
    else :
        break

# %%
images = driver.find_elements(By.CSS_SELECTOR, ".thumb")
count = 1
print(len(images))
# Out:
# 17

# %%
import os

# 저장 폴더가 없으면 생성
save_path = "./Image"
if not os.path.exists(save_path):
    os.makedirs(save_path)

for image in images:
    try:
        image.click()
        time.sleep(0.5)
        
        imgUrl = driver.find_element(
			By.XPATH,
			'//*[@id="main_pack"]/section[2]/div/div[2]/div/div/div[1]/div[1]/div/div/div[1]/div[1]/img'
        ).get_attribute("src")

        opener = urllib.request.build_opener()
        opener.addheaders = [
            ('User-Agent',
            'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')
        ]
        urllib.request.install_opener(opener)
        # f다음 경로 지정
        urllib.request.urlretrieve(imgUrl, f'./Image/{str(count)}.jpg')
        count = count + 1
    except Exception as e:
        print('e : ', e)
        pass
# Out:
# e :  Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="main_pack"]/section[2]/div/div[2]/div/div/div[1]/div[1]/div/div/div[1]/div[1]/img"}
#   (Session info: chrome=137.0.7151.103); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff7dd19fe75+79173]
# 	GetHandleVerifier [0x0x7ff7dd19fed0+79264]
# 	(No symbol) [0x0x7ff7dcf59e5a]
# 	(No symbol) [0x0x7ff7dcfb0586]
# 	(No symbol) [0x0x7ff7dcfb083c]
# 	(No symbol) [0x0x7ff7dd004247]
# 	(No symbol) [0x0x7ff7dcfd89af]
# 	(No symbol) [0x0x7ff7dd00100d]
# 	(No symbol) [0x0x7ff7dcfd8743]
# 	(No symbol) [0x0x7ff7dcfa14c1]
# 	(No symbol) [0x0x7ff7dcfa2253]
# 	GetHandleVerifier [0x0x7ff7dd46a2ad+3004797]
# 	GetHandleVerifier [0x0x7ff7dd4646fd+2981325]
# 	GetHandleVerifier [0x0x7ff7dd483350+3107360]
# 	GetHandleVerifier [0x0x7ff7dd1ba9fe+188622]
# ...

# %%
# 구글용
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import urllib.request

searchKey = input('검색 키워드 입력:')

driver = webdriver.Chrome()
driver.get("https://www.google.co.kr/imghp?hl=ko&tab=wi&authuser=0&ogbl")
elem = driver.find_element("name", "q")

elem.send_keys(searchKey)
elem.send_keys(Keys.RETURN)

SCROLL_PAUSE_TIME = 2
# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)
    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        try:
            driver.find_element(By.CSS_SELECTOR, ".mye4qd").click()
        except:
            break
    last_height = new_height

images = driver.find_elements(By.CSS_SELECTOR, ".rg_i.Q4LuWd")
count = 1
for image in images:
    try:
        image.click()
        time.sleep(0.5)
        
        imgUrl = driver.find_element(
			By.XPATH,
			'//*[@id="Sva75c"]/div[2]/div[2]/div[2]/div[2]/c-wiz/div/div/div/div[3]/div[1]/a/img[1]'
        ).get_attribute("src")
        
        print(imgUrl)

        opener = urllib.request.build_opener()
        opener.addheaders = [
            ('User-Agent',
            'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')
        ]
        urllib.request.install_opener(opener)
        # f다음 경로 지정
        urllib.request.urlretrieve(imgUrl, f'./Image/{str(count)}.jpg')
        count = count + 1
    except Exception as e:
        print('e : ', e)
        pass

driver.close()
